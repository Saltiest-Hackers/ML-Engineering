# %%
from google.cloud import bigquery
from google.oauth2 import service_account

credentials = service_account.Credentials.from_service_account_file(
    "../My First Project-801cca1315e6.json",
    scopes=["https://www.googleapis.com/auth/cloud-platform"],
)
client = bigquery.Client(
    credentials=credentials,
    project=credentials.project_id,
)

hn_dataset_ref = client.dataset('hacker_news', project='bigquery-public-data')

hn_dset = client.get_dataset(hn_dataset_ref)

[x.table_id for x in client.list_tables(hn_dset)]
# Out:
# ['comments', 'full', 'full_201510', 'stories']

# %%
df = client.query("""
SELECT *
FROM `bigquery-public-data.hacker_news.full`
ORDER BY time DESC
LIMIT 500000;
""").result().to_dataframe()

# %%
df.head()
# Out:
#   title   url                                               text  dead  \
# 0  None  None  I will not disagree with you on AngelScript&#x...  None
# 1  None  None  Fun story: a friend of mine works as an engine...  None
# 2  None  None  These are welcome suggestions, but habenaro sa...  None
# 3  None  None  Yes.<p><a href="https:&#x2F;&#x2F;www.nytimes....  None
# 4  None  None  Google spreads a lot of FUD (right or wrong) a...  None
#
#               by  score        time                 timestamp     type  \
# 0     hackkitten    NaN  1583143702 2020-03-02 10:08:22+00:00  comment
# 1         rawfan    NaN  1583143697 2020-03-02 10:08:17+00:00  comment
# 2          dunco    NaN  1583143689 2020-03-02 10:08:09+00:00  comment
# 3  inferiorhuman    NaN  1583143665 2020-03-02 10:07:45+00:00  comment
# 4        revicon    NaN  1583143650 2020-03-02 10:07:30+00:00  comment
#
#          id      parent  descendants ranking deleted
# 0  22463107  22457777.0          NaN    None    None
# 1  22463106  22461301.0          NaN    None    None
# 2  22463105  22462570.0          NaN    None    None
# 3  22463104  22461550.0          NaN    None    None
# 4  22463103  22461128.0          NaN    None    None
